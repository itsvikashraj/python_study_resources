# %% [markdown]
# **Setting up Pandas Enviroment**

# %%
import pandas as pd

# %%
url = "https://drive.google.com/uc?id=1I56ajKEYvFpFlDuM4VwvJirPHJ9fNSAb"
df = pd.read_csv(url)

# %%
df
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# CHECKING DATA TYPES OF DATASET

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
#CHECKING NULL VALUES

# %%
df.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
#FILLING NULL VALUES

# %%
df['Release_Date'].fillna("December 20, 2018",inplace = True)

# %%
df['Cast'].fillna("unknown",inplace = True)

# %%
df['Director'].fillna("unknown",inplace = True)

# %%
df.groupby('Rating').sum()
# Out:
#                                                     Show_Id  \
# Rating
# G         s156s228s409s486s487s488s489s709s710s711s1204s...
# NC-17                                        s997s3519s5937
# NR        s26s63s116s221s300s318s327s562s607s675s682s717...
# PG        s146s152s154s164s165s251s255s256s263s393s401s4...
# PG-13     s4s5s45s51s72s73s80s95s97s99s101s119s122s155s2...
# R         s3s8s15s18s66s69s75s84s85s90s105s121s123s127s1...
# TV-14     s9s16s17s19s21s22s23s24s25s29s31s34s35s39s41s4...
# TV-G      s32s33s114s159s187s198s199s247s250s365s381s414...
# TV-MA     s1s2s6s7s10s11s12s13s14s27s28s30s37s38s40s42s4...
# TV-PG     s20s36s47s79s82s96s100s102s135s136s138s141s143...
# TV-Y      s56s178s179s180s234s243s277s400s435s520s521s59...
# TV-Y7     s109s112s163s168s245s286s397s412s413s434s524s5...
# TV-Y7-FV                     s1663s3594s3602s3669s4242s4590
# UR                                s2485s2954s5523s5574s7729
#
# ...

# %%
df['Rating'].fillna("a",inplace = True)

# %%
sample = df.groupby(['Country']).count()['Show_Id']

# %% [markdown]
# **Setting up pandas**

# %%
pd.set_option('display.max_rows',50)

# %%
df['Country'].fillna("United States",inplace = True)

# %%
sample.sort_values(ascending = False)
# Out:
# Country
# United States                        2556
# India                                 923
# United Kingdom                        397
# Japan                                 226
# South Korea                           183
#                                      ...
# Indonesia, South Korea, Singapore       1
# Indonesia, United Kingdom               1
# Indonesia, United States                1
# Iran, France                            1
# Zimbabwe                                1
# Name: Show_Id, Length: 681, dtype: int64

# %%
df.isnull().sum()
# Out:
# Show_Id         0
# Category        0
# Title           0
# Director        0
# Cast            0
# Country         0
# Release_Date    0
# Rating          0
# Duration        0
# Type            0
# Description     0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
df.sample(20)
# Out:
#      Show_Id Category                              Title  \
# 5296   s5296    Movie        Rugrats in Paris: The Movie
# 4892   s4892    Movie  Pocoyo Halloween: Space Halloween
# 4502   s4503  TV Show                   Nobody's Looking
# 3691   s3692  TV Show             Lo que la vida me robó
# 3276   s3277    Movie                             Kaalia
# 225     s226  TV Show     A Series of Unfortunate Events
# 1774   s1775  TV Show                      Disappearance
# 5051   s5051  TV Show                   Rabbids Invasion
# 6196   s6196    Movie                           The Call
# 5478   s5478    Movie      Secrets of Underground London
# 3816   s3817    Movie                        Luka Chuppi
# 6862   s6861    Movie                     The Seven Five
# 6253   s6253    Movie                         The Croods
# 4134   s4135  TV Show                      Miss Dynamite
# 5632   s5632  TV Show                      Singles Villa
# ...

# %%
df[215:220]
# Out:
#     Show_Id Category                     Title          Director  \
# 215    s216    Movie             A Perfect Man  Kees Van Oostrum
# 216    s217    Movie           A Plastic Ocean           unknown
# 217    s218    Movie  A Princess for Christmas    Michael Damian
# 218    s219  TV Show           A Queen Is Born      Carla Barros
# 219    s220    Movie         A Remarkable Tale  Marina Seresesky
#
#                                                   Cast  \
# 215  Liev Schreiber, Jeanne Tripplehorn, Joelle Car...
# 216                                     Tanya Streeter
# 217  Katie McGrath, Sir Roger Moore, Sam Heughan, T...
# 218                      Gloria Groove, Alexia Twister
# 219  Carmen Machi, Pepón Nieto, Kiti Mánver, Jon Ko...
#
#                        Country       Release_Date Rating  Duration  \
# 215              United States       June 6, 2019      R    94 min
# 216  United Kingdom, Hong Kong    October 4, 2019  TV-14   100 min
# ...

# %%
df['Date_N'] = pd.to_datetime(df['Release_Date'],errors = "coerce")

# %%
df['Date_N'].sample(10)
# Out:
# 6318   2018-08-24
# 648    2015-03-06
# 88     2018-03-01
# 3272   2018-03-01
# 758    2020-10-01
# 3485   2017-02-01
# 3779   2020-04-10
# 2668   2019-01-12
# 1332   2020-12-12
# 3445   2017-09-08
# Name: Date_N, dtype: datetime64[ns]

# %%
df.groupby('Category').count()['Show_Id']
# Out:
# Category
# Movie      5379
# TV Show    2410
# Name: Show_Id, dtype: int64

# %%
df['Date_N'].fillna("2020-05-07")
# Out:
# 0      2020-08-14
# 1      2016-12-23
# 2      2018-12-20
# 3      2017-11-16
# 4      2020-01-01
#           ...
# 7784   2020-10-19
# 7785   2019-03-02
# 7786   2020-09-25
# 7787   2020-10-31
# 7788   2020-03-01
# Name: Date_N, Length: 7789, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      7789 non-null   object
#  4   Cast          7789 non-null   object
#  5   Country       7789 non-null   object
#  6   Release_Date  7789 non-null   object
#  7   Rating        7789 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
#  11  Date_N        7701 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), object(11)
# memory usage: 730.3+ KB

# %%
df['Date_N']= pd.to_datetime(df['Date_N'])

# %%
df.sample(10)
# Out:
#      Show_Id Category                                  Title  \
# 1011   s1012    Movie    Bob Lazar: Area 51 & Flying Saucers
# 2647   s2648  TV Show  Hatchimals | Adventures in Hatchtopia
# 7345   s7344    Movie                              Underdogs
# 4287   s4288  TV Show                            Murder Maps
# 6917   s6916    Movie           The Super Parental Guardians
# 6631   s6630  TV Show                   The Magic School Bus
# 6855   s6854  TV Show                             The Search
# 6381   s6380  TV Show                   The Furchester Hotel
# 2238   s2239  TV Show                        Forest of Piano
# 6314   s6313  TV Show                          The Dream Job
#
#                            Director  \
# 1011  Jeremy Kenyon Lockyer Corbell
# 2647                        unknown
# 7345           Juan José Campanella
# 4287                        unknown
# 6917                   Joyce Bernal
# 6631                        unknown
# ...

# %%
df[df['Title'].str.contains("Aagey Se Right")]
# Out:
#     Show_Id Category           Title          Director  \
# 265    s266    Movie  Aagey Se Right  Indrajit Nattoji
#
#                                                   Cast Country  \
# 265  Shreyas Talpade, Kay Kay Menon, Shiv Pandit, S...   India
#
#          Release_Date Rating Duration  \
# 265  November 1, 2018  TV-14  117 min
#
#                                                  Type  \
# 265  Comedies, International Movies, Music & Musicals
#
#                                            Description     Date_N
# 265  A cop full of self-doubt loses his gun five da... 2018-11-01

# %%
#MOST PRODUCTS RELEASE YEAR
rl_yr = df['Date_N'].dt.year.value_counts()
#draw graph

# %%
rl_yr.head(10).plot(kind = "bar")
# Out:
# <Axes: xlabel='Date_N'>

# %%
#GROUPED BY MOVIES & TV SHOWS

# %%
df.shape
# Out:
# (7789, 12)

# %%
mvtv= df.groupby(['Category']).count()['Show_Id']

# %%
mvtv
# Out:
# Category
# Movie      5379
# TV Show    2410
# Name: Show_Id, dtype: int64

# %%
mvtv.plot(kind = "bar")
# Out:
# <Axes: xlabel='Category'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      7789 non-null   object
#  4   Cast          7789 non-null   object
#  5   Country       7789 non-null   object
#  6   Release_Date  7789 non-null   object
#  7   Rating        7789 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
#  11  Date_N        7701 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), object(11)
# memory usage: 730.3+ KB

# %%
df['year']=df['Date_N'].dt.year

# %%
df.head(1)
# Out:
#   Show_Id Category Title Director  \
# 0      s1  TV Show    3%  unknown
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          Description     Date_N    year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0

# %%
mvtvs = df.groupby(['year','Category']).count()['Show_Id']

# %%
mvtvs.plot(kind="bar")
# Out:
# <Axes: xlabel='year,Category'>

# %%
#MOVIES RELEASED IN 2020 YEAR

# %%
df3 = str(len(df[(df['Release_Date']=='2017') & (df['Category']=="TV Show")]))

# %%
df3 = str(len(df[(df['Category']== "Movie")&(df['year']==2020)]))

# %%
df3
# Out:
# '1313'

# %%
df[(df['Category']== "Movie")&(df['year']==2020)]
# Out:
#      Show_Id Category                                    Title  \
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# 14       s15    Movie                                     3022
# 27       s28    Movie                                   #Alive
# 28       s29    Movie            #AnneFrank - Parallel Stories
# ...      ...      ...                                      ...
# 7762   s7761    Movie                                Zaki Chan
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7786   s7785    Movie                        Zulu Man in Japan
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                          Director  \
# 4                  Robert Luketic
# 6                 Yasir Al Yasiri
# 14                     John Suits
# 27                         Cho Il
# ...

# %%
print('THERE ARE 1313 MOVIES RELEASED IN 2020')
# Out:
# THERE ARE 1313 MOVIES RELEASED IN 2020

# %%
#TV SHOWS RELEASED IN 2020 YEAR

# %%
df.Category
# Out:
# 0       TV Show
# 1         Movie
# 2         Movie
# 3         Movie
# 4         Movie
#          ...
# 7784      Movie
# 7785      Movie
# 7786      Movie
# 7787    TV Show
# 7788      Movie
# Name: Category, Length: 7789, dtype: object

# %%
df.head(1)
# Out:
#   Show_Id Category Title Director  \
# 0      s1  TV Show    3%  unknown
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          Description     Date_N    year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0

# %%
tvshows = df[(df['Category']=="TV Show")&(df['year']==2020)]

# %%
tvshows.shape
# Out:
# (696, 13)

# %%
print("there ara 696 movie released in 2020")
# Out:
# there ara 696 movie released in 2020

# %%
#TOP 10 DIRECTORS CONTRIBUTE TO THE PRODUCTIONS

# %%
df[0:1]
# Out:
#   Show_Id Category Title Director  \
# 0      s1  TV Show    3%  unknown
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          Description     Date_N    year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0

# %%
dir = df.groupby(['Director']).count()['Show_Id'].sort_values(ascending = False)

# %%
dir.head(10)
# Out:
# Director
# unknown                   2388
# Raúl Campos, Jan Suter      18
# Marcus Raboy                16
# Jay Karas                   14
# Cathy Garcia-Molina         13
# Martin Scorsese             12
# Youssef Chahine             12
# Jay Chapman                 12
# Steven Spielberg            10
# David Dhawan                 9
# Name: Show_Id, dtype: int64

# %%
#'Horror Movies' RELEASED IN 2020

# %%
df.groupby(['Type']).count()['Show_Id']
# Out:
# Type
# Action & Adventure                                              99
# Action & Adventure, Anime Features, Children & Family Movies     3
# Action & Adventure, Anime Features, Classic Movies               1
# Action & Adventure, Anime Features, Horror Movies                1
# Action & Adventure, Anime Features, International Movies        28
#                                                                 ..
# TV Horror, TV Mysteries, Teen TV Shows                           1
# TV Horror, Teen TV Shows                                         1
# TV Sci-Fi & Fantasy, TV Thrillers                                1
# TV Shows                                                        12
# Thrillers                                                       49
# Name: Show_Id, Length: 492, dtype: int64

# %%
horror = df[(df['Category']=="Movie")&(df['year']==2020)&(df['Type']=="Horror Movies")]

# %%
horror[['Show_Id','Category','Title','Release_Date','Type']]
# Out:
#      Show_Id Category                    Title       Release_Date  \
# 261     s262    Movie                   A.M.I.    October 1, 2020
# 1654   s1655    Movie                  Deadcon   January 16, 2020
# 2165   s2166    Movie      Final Destination 3    January 1, 2020
# 2286   s2287    Movie          Friday the 13th    January 1, 2020
# 2405   s2406    Movie            Ghosts of War  November 25, 2020
# 2422   s2423    Movie  Girl on the Third Floor  February 22, 2020
# 2833   s2834    Movie       House of the Witch   October 11, 2020
# 4903   s4903    Movie                 Polaroid   February 9, 2020
# 4990   s4990    Movie               Prom Night  November 12, 2020
# 5637   s5637    Movie                    Siren    January 1, 2020
# 6082   s6082    Movie    The Amityville Horror    January 1, 2020
# 6352   s6351    Movie    The Final Destination    January 1, 2020
#
#                Type
# 261   Horror Movies
# 1654  Horror Movies
# 2165  Horror Movies
# 2286  Horror Movies
# ...

# %%
#TV SHOWS & MOVIES WHICH TOM CRUISE CASTED

# %%
tom = df[df['Cast'].str.contains("Tom Cruise")]

# %%
tom[['Show_Id','Category','Cast','Type','year']]
# Out:
#      Show_Id Category                                               Cast  \
# 3860   s3861    Movie  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...
# 5071   s5071    Movie  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...
#
#                             Type    year
# 3860  Dramas, Independent Movies  2020.0
# 5071      Classic Movies, Dramas  2019.0

# %%
#DIFFERENT RATING USED BY NETFLIX

# %%
df.head(1)
# Out:
#   Show_Id Category Title Director  \
# 0      s1  TV Show    3%  unknown
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          Description     Date_N    year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0

# %%
rt = df['Rating'].value_counts()

# %%
print(" diffrent rating used by netflix are:-")
print(rt)
# Out:
#  diffrent rating used by netflix are:-
# Rating
# TV-MA       2865
# TV-14       1931
# TV-PG        806
# R            665
# PG-13        386
# TV-Y         280
# TV-Y7        271
# PG           247
# TV-G         194
# NR            84
# G             39
# a              7
# TV-Y7-FV       6
# UR             5
# NC-17          3
# Name: count, dtype: int64

# %%
#HOW MANY TV SHOWS GOT 'TV-14' RATINGS

# %%
df[df['Rating'].str.contains("TV-14")]
# Out:
#      Show_Id Category                     Title            Director  \
# 8         s9    Movie                       706       Shravan Kumar
# 15       s16    Movie                    Oct-01      Kunle Afolayan
# 16       s17  TV Show                    Feb-09             unknown
# 18       s19    Movie                    15-Aug  Swapnaneel Jayakar
# 20       s21    Movie      ​​Kuch Bheege Alfaaz                Onir
# ...      ...      ...                       ...                 ...
# 7765   s7764    Movie                     Zenda      Avadhoot Gupte
# 7766   s7765    Movie                      Zero          Aanand Rai
# 7770   s7769    Movie  Zindagi Kitni Haseen Hay       Anjum Shahzad
# 7771   s7770    Movie  Zindagi Na Milegi Dobara         Zoya Akhtar
# 7785   s7784    Movie                    Zubaan         Mozez Singh
#
#                                                    Cast        Country  \
# 8     Divya Dutta, Atul Kulkarni, Mohan Agashe, Anup...          India
# ...

# %%
print("1931 movies got TV-14 Rating")
# Out:
# 1931 movies got TV-14 Rating

# %%
#HOW MANY TV SHOWS GOT 'R' RATING AFTER 2010

# %%
r = df[df['Rating']=="R"].value_counts()

# %%
r.shape
# Out:
# (665,)

# %%
print("665 movie got r rating")
# Out:
# 665 movie got r rating

# %%
#MAX DURATION IN MOVIES

# %%
df.head(1)
# Out:
#   Show_Id Category Title Director  \
# 0      s1  TV Show    3%  unknown
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          Description     Date_N    year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0

# %%
df[['time','season']]=df['Duration'].str.split(' ',expand = True)

# %%
sf = df[df['Category']== "Movie"]

# %%
max_time = sf['time'].max()  # Get the maximum value in the 'time' column
sf[sf['time'] == max_time]   # Filter the DataFrame to include only rows where 'time' equals the maximum value
# Out:
#      Show_Id Category                                        Title  \
# 27       s28    Movie                                       #Alive
# 33       s34    Movie                                 #realityhigh
# 42       s43    Movie                  Çok Filim Hareketler Bunlar
# 121     s122    Movie                               50 First Dates
# 147     s148    Movie      A Babysitter's Guide to Monster Hunting
# ...      ...      ...                                          ...
# 7449   s7448    Movie                                          VS.
# 7527   s7526    Movie                        Welcome Mr. President
# 7559   s7558    Movie                         What Keeps You Alive
# 7638   s7637    Movie  Winter on Fire: Ukraine's Fight for Freedom
# 7784   s7783    Movie                                         Zozo
#
#                Director                                               Cast  \
# 27               Cho Il                           Yoo Ah-in, Park Shin-hye
# ...

# %%
#MAX TV SERIES SEASONS

# %%
df.head(4)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%            unknown
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# ...

# %%
sg = df[(df['Category']=="TV Show")&(df['season']=='Seasons')]

# %%
sg.head(1)
# Out:
#   Show_Id Category Title Director  \
# 0      s1  TV Show    3%  unknown
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          Description     Date_N    year time  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0    4
#
#     season
# 0  Seasons

# %%
max_tv = sg['time'].max()

# %%
max_tv
# Out:
# '9'

# %%
sg[sg['time']=='9']
# Out:
#      Show_Id Category                     Title            Director  \
# 468     s469  TV Show     American Horror Story             unknown
# 1181   s1182  TV Show          Call the Midwife  Philippa Lowthorpe
# 1431   s1432  TV Show  Club Friday The Series 6             unknown
# 2237   s2238  TV Show            Forensic Files             unknown
# 4404   s4405  TV Show                    Naruto         Hayato Date
# 5819   s5819  TV Show                Still Game             unknown
# 6720   s6719  TV Show         The Office (U.S.)             unknown
# 6985   s6984  TV Show          The Walking Dead             unknown
#
#                                                    Cast         Country  \
# 468   Evan Peters, Sarah Paulson, Jessica Lange, Den...   United States
# 1181  Vanessa Redgrave, Bryony Hannah, Helen George,...  United Kingdom
# 1431  Puttichai Kasetsin, Kongtoranin Lalana, Preech...   United States
# ...

# %%
#TOP 10 COUNTRY WITH MOST movie watchtime,graph

# %%
test = df[df['Category']=="Movie"]

# %%
test[0:4]
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating Duration  \
# 1  December 23, 2016  TV-MA   93 min
# 2  December 20, 2018      R   78 min
# 3  November 16, 2017  PG-13   80 min
# 4    January 1, 2020  PG-13  123 min
#
#                                                 Type  \
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# ...

# %%
df['Country'].value_counts()
# Out:
# Country
# United States                                                   3063
# India                                                            923
# United Kingdom                                                   397
# Japan                                                            226
# South Korea                                                      183
#                                                                 ...
# Russia, United States, China                                       1
# Italy, Switzerland, France, Germany                                1
# United States, United Kingdom, Canada                              1
# United States, United Kingdom, Japan                               1
# Sweden, Czech Republic, United Kingdom, Denmark, Netherlands       1
# Name: count, Length: 681, dtype: int64

# %%
h = df['Country'].value_counts().head(10)

# %%
h.plot(kind = "bar")
# Out:
# <Axes: xlabel='Country'>

# %%
#TOP 10 COUNTRY WITH MOST TV SHOWS,graph

# %%
test2 = df[df['Category']=="TV Show"]

# %%
test2['Country'].value_counts()
# Out:
# Country
# United States                                                982
# United Kingdom                                               204
# Japan                                                        157
# South Korea                                                  147
# India                                                         71
#                                                             ...
# Canada, United States, United Kingdom, France, Luxembourg      1
# United States, Italy                                           1
# Chile, Italy                                                   1
# Canada, United Kingdom                                         1
# United States, France, South Korea, Indonesia                  1
# Name: count, Length: 183, dtype: int64

# %%
t = test2['Country'].value_counts().head(10)

# %%
t.plot(kind = "bar")
# Out:
# <Axes: xlabel='Country'>

# %%
#MOVIES COUNT BY YEARS,graph

# %%
test3 = df[df['Category']=="Movie"]

# %%
test4 = pd.DataFrame(test3.groupby(['year']).count()['Show_Id'])

# %%
z = test3['year'].value_counts()

# %%
z.plot(kind="bar")
# Out:
# <Axes: xlabel='year'>

# %%
test4.plot(kind = "bar")
# Out:
# <Axes: xlabel='year'>

# %%
#TV SHOWS COUNT BY YEARS,graph

# %%
test5 = df[df['Category']=="TV Show"]

# %%
test6 = pd.DataFrame(test5.groupby(['year']).count()['Show_Id'])

# %%
test6
# Out:
#         Show_Id
# year
# 2008.0        1
# 2013.0        4
# 2014.0        5
# 2015.0       21
# 2016.0      174
# 2017.0      337
# 2018.0      416
# 2019.0      639
# 2020.0      696
# 2021.0       29

# %%
test4
# Out:
#         Show_Id
# year
# 2008.0        1
# 2009.0        2
# 2010.0        1
# 2011.0       13
# 2012.0        3
# 2013.0        6
# 2014.0       19
# 2015.0       58
# 2016.0      258
# 2017.0      864
# 2018.0     1255
# 2019.0     1498
# 2020.0     1313
# 2021.0       88

# %%
te= test6['Show_Id'].sort_values(ascending = False)

# %%
te.plot(kind = "bar")
# Out:
# <Axes: xlabel='year'>
